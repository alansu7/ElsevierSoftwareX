# %% [markdown]
# **To** run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://github.com/unslothai/unsloth#installation-instructions---conda).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save) (eg for Llama.cpp).
#
# [NEW] ORPO support is finally here thanks to [oKatanaaa](https://github.com/oKatanaaa) and [AT&Dev](https://huggingface.co/AtAndDev)
#
# ORPO merges the SFT and DPO steps into 1. Before one had to do a SFT, then DPO. ORPO now requires only 1 step.

# %%
# %%capture
# !pip install unsloth
# Also get the latest nightly Unsloth!
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"

# %% [markdown]
# * We support Llama, Mistral, CodeLlama, TinyLlama, Vicuna, Open Hermes etc
# * And Yi, Qwen ([llamafied](https://huggingface.co/models?sort=trending&search=qwen+llama)), Deepseek, all Llama, Mistral derived archs.
# * We support 16bit LoRA or 4bit QLoRA. Both 2x faster.
# * `max_seq_length` can be set to anything, since we do automatic RoPE Scaling via [kaiokendev's](https://kaiokendev.github.io/til) method.
# * [**NEW**] With [PR 26037](https://github.com/huggingface/transformers/pull/26037), we support downloading 4bit models **4x faster**! [Our repo](https://huggingface.co/unsloth) has Llama, Mistral 4bit models.

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 4096 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Mistral-Nemo-Instruct-2407-bnb-4bit",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2024.12.4: Fast Mistral patching. Transformers:4.47.0.
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 7.5. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json:   0%|          | 0.00/165k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.31G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/158 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/181k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.26M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2024.12.4 patched 40 layers with 40 QKV layers, 40 O layers and 40 MLP layers.

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We now use a special ORPO style dataset from [recipe-research](https://huggingface.co/datasets/reciperesearch/dolphin-sft-v0.1-preference).
#
# You need at least 3 columns:
# * Instruction
# * Accepted
# * Rejected
#
# For example:
# * Instruction: "What is 2+2?"
# * Accepted: "The answer is 4"
# * Rejected: "The answer is 5"
#
# The goal of ORPO is to penalize the "rejected" samples, and increase the likelihood of "accepted" samples. [recipe-research](https://huggingface.co/datasets/reciperesearch/dolphin-sft-v0.1-preference) essentially used Mistral to generate the "rejected" responses, and used GPT-4 to generated the "accepted" responses.

# %%
# The data must be formatted with appropriate prompt template first.
# See details here: https://github.com/huggingface/trl/blob/main/examples/scripts/orpo.py

alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN

def format_prompt(sample):
    instruction = sample["instruction"]
    input       = sample["input"]
    accepted    = sample["accepted"]
    rejected    = sample["rejected"]

    # ORPOTrainer expects prompt/chosen/rejected keys
    # See: https://huggingface.co/docs/trl/main/en/orpo_trainer
    sample["prompt"]   = alpaca_prompt.format(instruction, input, "")
    sample["chosen"]   = accepted + EOS_TOKEN
    sample["rejected"] = rejected + EOS_TOKEN
    return sample
pass

from datasets import load_dataset
dataset = load_dataset("iecjsu/airline-sentiment-ORPO-train")["train"]
dataset = dataset.map(format_prompt,)
# Out:
# airline-ORPO-train-balanced.jsonl:   0%|          | 0.00/1.47M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/5670 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5670 [00:00<?, ? examples/s]

# %% [markdown]
# Let's print out some examples to see how the dataset should look like

# %%
import pprint
row = dataset[1]
print('INSTRUCTION: ' + '=' * 50)
pprint.pprint(row["prompt"])
print('ACCEPTED: ' + '=' * 50)
pprint.pprint(row["chosen"])
print('REJECTED: ' + '=' * 50)
pprint.pprint(row["rejected"])
# Out:
# INSTRUCTION: ==================================================
# ('Below is an instruction that describes a task, paired with an input that '
#  'provides further context. Write a response that appropriately completes the '
#  'request.\n'
#  '\n'
#  '### Instruction:\n'
#  'Classify the input using one of these labels: neutral, positive, and '
#  'negative: \n'
#  '\n'
#  '### Input:\n'
#  '@united sure, but 8 different texts changing time &amp; gate (especially '
#  'locations across the entire concourse). That just seemed a little off.\n'
#  '\n'
#  '### Response:\n')
# ACCEPTED: ==================================================
# 'negative</s>'
# REJECTED: ==================================================
# 'neutral, positive</s>'

# %%
# Enable reward modelling stats
from unsloth import PatchDPOTrainer
PatchDPOTrainer()

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `ORPOTrainer`! More docs here: [TRL ORPO docs](https://huggingface.co/docs/trl/main/en/orpo_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!

# %%
from trl import ORPOConfig, ORPOTrainer
from unsloth import is_bfloat16_supported

orpo_trainer = ORPOTrainer(
    model = model,
    train_dataset = dataset,
    tokenizer = tokenizer,
    args = ORPOConfig(
        max_length = max_seq_length,
        max_prompt_length = max_seq_length//2,
        max_completion_length = max_seq_length//2,
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        beta = 0.1,
        logging_steps = 1,
        optim = "adamw_8bit",
        lr_scheduler_type = "linear",
        max_steps = 200, # Change to num_train_epochs = 1 for full training runs
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        output_dir = "outputs",
        report_to = "none", # Use this for WandB etc
    ),
)

# %%
orpo_trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 5,670 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 200
#  "-____-"     Number of trainable parameters = 57,016,320
#     <div>
#
#       <progress value='200' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [200/200 31:27, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>rewards / chosen</th>
#       <th>rewards / rejected</th>
#       <th>rewards / accuracies</th>
#       <th>rewards / margins</th>
#       <th>logps / rejected</th>
#       <th>logps / chosen</th>
#       <th>logits / rejected</th>
#       <th>logits / chosen</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.653600</td>
#       <td>-0.069792</td>
#       <td>-0.537476</td>
#       <td>1.000000</td>
#       <td>0.467684</td>
#       <td>-5.374762</td>
#       <td>-0.697923</td>
#       <td>-2.632972</td>
#       <td>-2.650948</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.941600</td>
#       <td>-0.044792</td>
#       <td>-0.481486</td>
#       <td>1.000000</td>
#       <td>0.436694</td>
#       <td>-4.814860</td>
#       <td>-0.447919</td>
#       <td>-2.999462</td>
#       <td>-2.989325</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2
td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>2.371300</td>
#       <td>-0.040317</td>
#       <td>-0.400784</td>
#       <td>1.000000</td>
#       <td>0.360467</td>
#       <td>-4.0
# TrainOutput(global_step=200, training_loss=2.1274267452955247, metrics={'train_runtime': 1896.9957, 'train_samples_per_second': 0.843, 'train_steps_per_second': 0.105, 'total_flos': 0.0, 'train_loss': 2.1274267452955247, 'epoch': 0.2821869488536155})

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! You can change the instruction and input - leave the output blank!

# %% [markdown]
#  You can also use a `TextStreamer` for continuous inference - so you can see the generation token by token, instead of waiting the whole time!

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("lora_model") # Local saving
tokenizer.save_pretrained("lora_model")
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
# tokenizer.push_to_hub("your_name/lora_model", token = "...") # Online saving
# Out:
# ('lora_model/tokenizer_config.json',
#  'lora_model/special_tokens_map.json',
#  'lora_model/tokenizer.json')

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %% [markdown]
# You can also use Hugging Face's `AutoModelForPeftCausalLM`. Only use this if you do not have `unsloth` installed. It can be hopelessly slow, since `4bit` model downloading is not supported, and Unsloth's **inference is 2x faster**.

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model", tokenizer,)
if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if True: model.save_pretrained_gguf("Mistral-Nemo-IT-2407-ORPOall-f16", tokenizer, quantization_method = "f16")
if True: model.push_to_hub_gguf("Mistral-Nemo-IT-2407-ORPOall-f16", tokenizer, quantization_method = "f16", token = "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")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")
# Out:
# Unsloth: Kaggle/Colab has limited disk space. We need to delete the downloaded
# model which will save 4-16GB of disk space, allowing you to save on Kaggle/Colab.
# Unsloth: Will remove a cached repo with size 8.3G
# Unsloth: Merging 4bit and LoRA weights to 16bit...
# Unsloth: Will use up to 34.39 out of 50.99 RAM for saving.
# Unsloth: Saving model... This might take 5 minutes ...
#  15%|█▌        | 6/40 [00:00<00:03, 10.07it/s]We will save to Disk and not RAM now.
# 100%|██████████| 40/40 [00:50<00:00,  1.26s/it]
# Unsloth: Saving tokenizer... Done.
# Done.
# Unsloth: Converting mistral model. Can use fast conversion = False.
# ==((====))==  Unsloth: Conversion from QLoRA to GGUF information
#    \\   /|    [0] Installing llama.cpp might take 3 minutes.
# O^O/ \_/ \    [1] Converting HF to GGUF 16bits might take 3 minutes.
# \        /    [2] Converting GGUF 16bits to ['f16'] might take 10 minutes each.
#  "-____-"     In total, you will have to wait at least 16 minutes.
#
# Unsloth: Installing llama.cpp. This might take 3 minutes...
# Unsloth: CMAKE detected. Finalizing some steps for installation.
# Unsloth: [1] Converting model at Mistral-Nemo-IT-2407-ORPOall-f16-v3 into f16 GGUF format.
# The output location will be /content/Mistral-Nemo-IT-2407-ORPOall-f16-v3/unsloth.F16.gguf
# This might take 3 minutes...
# INFO:hf-to-gguf:Loading model: Mistral-Nemo-IT-2407-ORPOall-f16-v3
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:gguf: loading model weight map from 'model.safetensors.index.json'
# INFO:hf-to-gguf:gguf: loading model part 'model-00001-of-00005.safetensors'
# INFO:hf-to-gguf:token_embd.weight,           torch.float16 --> F16, shape = {5120, 131072}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,       torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight,       torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,         torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.0.ffn_norm.weight,       torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.0.attn_k.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.0.attn_output.weight,    torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.0.attn_q.weight,         torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.0.attn_v.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.1.attn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.1.ffn_down.weight,       torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.1.ffn_gate.weight,       torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.1.ffn_up.weight,         torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.1.ffn_norm.weight,       torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.1.attn_k.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.1.attn_output.weight,    torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.1.attn_q.weight,         torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.1.attn_v.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.2.attn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.2.ffn_down.weight,       torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.2.ffn_gate.weight,       torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.2.ffn_up.weight,         torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.2.ffn_norm.weight,       torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.2.attn_k.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.2.attn_output.weight,    torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.2.attn_q.weight,         torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.2.attn_v.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.3.attn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.3.ffn_down.weight,       torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.3.ffn_gate.weight,       torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.3.ffn_up.weight,         torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.3.ffn_norm.weight,       torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.3.attn_k.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.3.attn_output.weight,    torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.3.attn_q.weight,         torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.3.attn_v.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.4.attn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.4.ffn_down.weight,       torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.4.ffn_gate.weight,       torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.4.ffn_up.weight,         torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.4.ffn_norm.weight,       torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.4.attn_k.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.4.attn_output.weight,    torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.4.attn_q.weight,         torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.4.attn_v.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.5.attn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.5.ffn_down.weight,       torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.5.ffn_gate.weight,       torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.5.ffn_up.weight,         torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.5.ffn_norm.weight,       torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.5.attn_k.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.5.attn_output.weight,    torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.5.attn_q.weight,         torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.5.attn_v.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.6.ffn_gate.weight,       torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.6.attn_k.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.6.attn_output.weight,    torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.6.attn_q.weight,         torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.6.attn_v.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00002-of-00005.safetensors'
# INFO:hf-to-gguf:blk.10.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.10.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.10.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.10.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.10.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.10.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.10.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.10.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.10.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.11.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.11.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.11.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.11.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.11.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.11.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.11.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.11.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.11.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.12.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.12.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.12.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.12.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.12.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.12.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.12.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.12.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.12.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.13.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.13.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.13.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.13.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.13.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.13.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.13.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.13.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.13.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.14.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.14.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.14.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.14.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.14.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.14.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.14.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.14.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.14.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.15.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.15.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.15.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.15.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.15.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.6.attn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.6.ffn_down.weight,       torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.6.ffn_up.weight,         torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.6.ffn_norm.weight,       torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.7.attn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.7.ffn_down.weight,       torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.7.ffn_gate.weight,       torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.7.ffn_up.weight,         torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:gguf.vocab:Adding 269443 merge(s).
# INFO:gguf.vocab:Setting special token type bos to 1
# INFO:gguf.vocab:Setting special token type eos to 2
# INFO:gguf.vocab:Setting special token type unk to 0
# INFO:gguf.vocab:Setting special token type pad to 10
# INFO:gguf.vocab:Setting add_bos_token to True
# INFO:gguf.vocab:Setting add_eos_token to False
# INFO:gguf.vocab:Setting chat_template to {%- if messages[0]["role"] == "system" %}
#     {%- set system_message = messages[0]["content"] %}
#     {%- set loop_messages = messages[1:] %}
# {%- else %}
#     {%- set loop_messages = messages %}
# {%- endif %}
# {%- if not tools is defined %}
#     {%- set tools = none %}
# {%- endif %}
# {%- set user_messages = loop_messages | selectattr("role", "equalto", "user") | list %}
#
# {#- This block checks for alternating user/assistant messages, skipping tool calling messages #}
# {%- set ns = namespace() %}
# {%- set ns.index = 0 %}
# {%- for message in loop_messages %}
#     {%- if not (message.role == "tool" or message.role == "tool_results" or (message.tool_calls is defined and message.tool_calls is not none)) %}
#         {%- if (message["role"] == "user") != (ns.index % 2 == 0) %}
#             {{- raise_exception("After the optional system message, conversation roles must alternate user/assistant/user/assistant/...") }}
#         {%- endif %}
#         {%- set ns.index = ns.index + 1 %}
#     {%- endif %}
# {%- endfor %}
#
# {{- bos_token }}
# {%- for message in loop_messages %}
#     {%- if message["role"] == "user" %}
#         {%- if tools is not none and (message == user_messages[-1]) %}
#             {{- "[AVAILABLE_TOOLS][" }}
#             {%- for tool in tools %}
#                 {%- set tool = tool.function %}
#                 {{- '{"type": "function", "function": {' }}
#                 {%- for key, val in tool.items() if key != "return" %}
#                     {%- if val is string %}
#                         {{- '"' + key + '": "' + val + '"' }}
#                     {%- else %}
#                         {{- '"' + key + '": ' + val|tojson }}
#                     {%- endif %}
#                     {%- if not loop.last %}
#                         {{- ", " }}
#                     {%- endif %}
#                 {%- endfor %}
#                 {{- "}}" }}
#                 {%- if not loop.last %}
#                     {{- ", " }}
#                 {%- else %}
#                     {{- "]" }}
#                 {%- endif %}
#             {%- endfor %}
#             {{- "[/AVAILABLE_TOOLS]" }}
#             {%- endif %}
#         {%- if loop.last and system_message is defined %}
#             {{- "[INST]" + system_message + "\n\n" + message["content"] + "[/INST]" }}
#         {%- else %}
#             {{- "[INST]" + message["content"] + "[/INST]" }}
#         {%- endif %}
#     {%- elif (message.tool_calls is defined and message.tool_calls is not none) %}
#         {{- "[TOOL_CALLS][" }}
#         {%- for tool_call in message.tool_calls %}
#             {%- set out = tool_call.function|tojson %}
#             {{- out[:-1] }}
#             {%- if not tool_call.id is defined or tool_call.id|length != 9 %}
#                 {{- raise_exception("Tool call IDs should be alphanumeric strings with length 9!") }}
#             {%- endif %}
#             {{- ', "id": "' + tool_call.id + '"}' }}
#             {%- if not loop.last %}
#                 {{- ", " }}
#             {%- else %}
#                 {{- "]" + eos_token }}
#             {%- endif %}
#         {%- endfor %}
#     {%- elif message["role"] == "assistant" %}
#         {{- message["content"] + eos_token}}
#     {%- elif message["role"] == "tool_results" or message["role"] == "tool" %}
#         {%- if message.content is defined and message.content.content is defined %}
#             {%- set content = message.content.content %}
#         {%- else %}
#             {%- set content = message.content %}
#         {%- endif %}
#         {{- '[TOOL_RESULTS]{"content": ' + content|string + ", " }}
#         {%- if not message.tool_call_id is defined or message.tool_call_id|length != 9 %}
#             {{- raise_exception("Tool call IDs should be alphanumeric strings with length 9!") }}
#         {%- endif %}
#         {{- '"call_id": "' + message.tool_call_id + '"}[/TOOL_RESULTS]' }}
#     {%- else %}
#         {{- raise_exception("Only user and assistant roles are supported, with the exception of an initial optional system message!") }}
#     {%- endif %}
# {%- endfor %}
#
# INFO:hf-to-gguf:Set model quantization version
# INFO:gguf.gguf_writer:Writing the following files:
# INFO:gguf.gguf_writer:/content/Mistral-Nemo-IT-2407-ORPOall-f16-v3/unsloth.F16.gguf: n_tensors = 363, total_size = 24.5G
# Writing: 100%|██████████| 24.5G/24.5G [02:00<00:00, 203Mbyte/s]
# INFO:hf-to-gguf:Model successfully exported to /content/Mistral-Nemo-IT-2407-ORPOall-f16-v3/unsloth.F16.gguf
# Unsloth: Conversion completed! Output location: /content/Mistral-Nemo-IT-2407-ORPOall-f16-v3/unsloth.F16.gguf
# Unsloth: Merging 4bit and LoRA weights to 16bit...
# Unsloth: Will use up to 34.6 out of 50.99 RAM for saving.
# Unsloth: Saving model... This might take 5 minutes ...
# 100%|██████████| 40/40 [00:50<00:00,  1.26s/it]
# Unsloth: Saving tokenizer... Done.
# Done.
# ==((====))==  Unsloth: Conversion from QLoRA to GGUF information
#    \\   /|    [0] Installing llama.cpp might take 3 minutes.
# O^O/ \_/ \    [1] Converting HF to GGUF 16bits might take 3 minutes.
# \        /    [2] Converting GGUF 16bits to ['f16'] might take 10 minutes each.
#  "-____-"     In total, you will have to wait at least 16 minutes.
#
# Unsloth: Installing llama.cpp. This might take 3 minutes...
# Unsloth: [1] Converting model at Mistral-Nemo-IT-2407-ORPOall-f16-v3 into f16 GGUF format.
# The output location will be /content/Mistral-Nemo-IT-2407-ORPOall-f16-v3/unsloth.F16.gguf
# This might take 3 minutes...
# INFO:hf-to-gguf:Loading model: Mistral-Nemo-IT-2407-ORPOall-f16-v3
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:gguf: loading model weight map from 'model.safetensors.index.json'
# INFO:hf-to-gguf:gguf: loading model part 'model-00001-of-00005.safetensors'
# INFO:hf-to-gguf:token_embd.weight,           torch.float16 --> F16, shape = {5120, 131072}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,       torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight,       torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,         torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.0.ffn_norm.weight,       torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.0.attn_k.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.0.attn_output.weight,    torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.0.attn_q.weight,         torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.0.attn_v.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.1.attn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.1.ffn_down.weight,       torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.1.ffn_gate.weight,       torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.1.ffn_up.weight,         torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.1.ffn_norm.weight,       torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.1.attn_k.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.1.attn_output.weight,    torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.1.attn_q.weight,         torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.1.attn_v.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.2.attn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.2.ffn_down.weight,       torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.2.ffn_gate.weight,       torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.2.ffn_up.weight,         torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.2.ffn_norm.weight,       torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.2.attn_k.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.2.attn_output.weight,    torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.2.attn_q.weight,         torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.2.attn_v.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.3.attn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.3.ffn_down.weight,       torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.3.ffn_gate.weight,       torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.3.ffn_up.weight,         torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.3.ffn_norm.weight,       torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.3.attn_k.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.3.attn_output.weight,    torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.3.attn_q.weight,         torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.3.attn_v.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.4.attn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.4.ffn_down.weight,       torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.4.ffn_gate.weight,       torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.4.ffn_up.weight,         torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.4.ffn_norm.weight,       torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.4.attn_k.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.4.attn_output.weight,    torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.4.attn_q.weight,         torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.4.attn_v.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.5.attn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.5.ffn_down.weight,       torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.5.ffn_gate.weight,       torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.5.ffn_up.weight,         torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.5.ffn_norm.weight,       torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.5.attn_k.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.5.attn_output.weight,    torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.5.attn_q.weight,         torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.5.attn_v.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.6.ffn_gate.weight,       torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.6.attn_k.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.6.attn_output.weight,    torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.6.attn_q.weight,         torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.6.attn_v.weight,         torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00002-of-00005.safetensors'
# INFO:hf-to-gguf:blk.10.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.10.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.10.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.10.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.10.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.10.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.10.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.10.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.10.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.11.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.11.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.11.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.11.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.11.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.11.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.11.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.11.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.11.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.12.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.12.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.12.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.12.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.12.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.12.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.12.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# ...
# INFO:hf-to-gguf:blk.27.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.27.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.27.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.27.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.27.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.27.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.27.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.28.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.28.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.28.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.28.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.28.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.28.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.28.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.28.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.28.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.29.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.29.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.29.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.29.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.29.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.29.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.29.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.29.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.29.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.30.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.30.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.30.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.30.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.30.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.30.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.30.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.30.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.30.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.31.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.31.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.31.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.31.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.31.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.31.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.31.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.31.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.31.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.32.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.32.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.32.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.32.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.32.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.32.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.32.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.32.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.32.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.33.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.33.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.33.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.33.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.33.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00005-of-00005.safetensors'
# INFO:hf-to-gguf:output.weight,               torch.float16 --> F16, shape = {5120, 131072}
# INFO:hf-to-gguf:blk.33.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.33.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.33.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.33.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.34.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.34.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.34.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.34.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.34.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.34.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.34.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.34.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.34.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.35.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.35.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.35.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.35.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.35.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.35.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.35.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.35.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.35.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.36.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.36.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.36.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.36.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.36.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.36.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.36.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.36.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.36.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.37.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.37.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.37.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.37.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.37.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.37.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.37.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.37.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.37.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.38.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.38.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.38.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.38.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.38.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.38.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.38.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.38.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.38.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.39.attn_norm.weight,     torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.39.ffn_down.weight,      torch.float16 --> F16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.39.ffn_gate.weight,      torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.39.ffn_up.weight,        torch.float16 --> F16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.39.ffn_norm.weight,      torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.39.attn_k.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.39.attn_output.weight,   torch.float16 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.39.attn_q.weight,        torch.float16 --> F16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.39.attn_v.weight,        torch.float16 --> F16, shape = {5120, 1024}
# INFO:hf-to-gguf:output_norm.weight,          torch.float16 --> F32, shape = {5120}
# INFO:hf-to-gguf:Set meta model
# INFO:hf-to-gguf:Set model parameters
# INFO:hf-to-gguf:gguf: context length = 1024000
# INFO:hf-to-gguf:gguf: embedding length = 5120
# INFO:hf-to-gguf:gguf: feed forward length = 14336
# INFO:hf-to-gguf:gguf: head count = 32
# INFO:hf-to-gguf:gguf: key-value head count = 8
# INFO:hf-to-gguf:gguf: rope theta = 1000000.0
# INFO:hf-to-gguf:gguf: rms norm epsilon = 1e-05
# INFO:hf-to-gguf:gguf: file type = 1
# INFO:hf-to-gguf:Set model tokenizer
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:gguf.vocab:Adding 269443 merge(s).
# INFO:gguf.vocab:Setting special token type bos to 1
# INFO:gguf.vocab:Setting special token type eos to 2
# INFO:gguf.vocab:Setting special token type unk to 0
# INFO:gguf.vocab:Setting special token type pad to 10
# INFO:gguf.vocab:Setting add_bos_token to True
# INFO:gguf.vocab:Setting add_eos_token to False
# INFO:gguf.vocab:Setting chat_template to {%- if messages[0]["role"] == "system" %}
#     {%- set system_message = messages[0]["content"] %}
#     {%- set loop_messages = messages[1:] %}
# {%- else %}
#     {%- set loop_messages = messages %}
# {%- endif %}
# {%- if not tools is defined %}
#     {%- set tools = none %}
# {%- endif %}
# {%- set user_messages = loop_messages | selectattr("role", "equalto", "user") | list %}
#
# {#- This block checks for alternating user/assistant messages, skipping tool calling messages #}
# {%- set ns = namespace() %}
# {%- set ns.index = 0 %}
# {%- for message in loop_messages %}
#     {%- if not (message.role == "tool" or message.role == "tool_results" or (message.tool_calls is defined and message.tool_calls is not none)) %}
#         {%- if (message["role"] == "user") != (ns.index % 2 == 0) %}
#             {{- raise_exception("After the optional system message, conversation roles must alternate user/assistant/user/assistant/...") }}
#         {%- endif %}
#         {%- set ns.index = ns.index + 1 %}
#     {%- endif %}
# {%- endfor %}
#
# {{- bos_token }}
# {%- for message in loop_messages %}
#     {%- if message["role"] == "user" %}
#         {%- if tools is not none and (message == user_messages[-1]) %}
#             {{- "[AVAILABLE_TOOLS][" }}
#             {%- for tool in tools %}
#                 {%- set tool = tool.function %}
#                 {{- '{"type": "function", "function": {' }}
#                 {%- for key, val in tool.items() if key != "return" %}
#                     {%- if val is string %}
#                         {{- '"' + key + '": "' + val + '"' }}
#                     {%- else %}
#                         {{- '"' + key + '": ' + val|tojson }}
#                     {%- endif %}
#                     {%- if not loop.last %}
#                         {{- ", " }}
#                     {%- endif %}
#                 {%- endfor %}
#                 {{- "}}" }}
#                 {%- if not loop.last %}
#                     {{- ", " }}
#                 {%- else %}
#                     {{- "]" }}
#                 {%- endif %}
#             {%- endfor %}
#             {{- "[/AVAILABLE_TOOLS]" }}
#             {%- endif %}
#         {%- if loop.last and system_message is defined %}
#             {{- "[INST]" + system_message + "\n\n" + message["content"] + "[/INST]" }}
#         {%- else %}
#             {{- "[INST]" + message["content"] + "[/INST]" }}
#         {%- endif %}
#     {%- elif (message.tool_calls is defined and message.tool_calls is not none) %}
#         {{- "[TOOL_CALLS][" }}
#         {%- for tool_call in message.tool_calls %}
#             {%- set out = tool_call.function|tojson %}
#             {{- out[:-1] }}
#             {%- if not tool_call.id is defined or tool_call.id|length != 9 %}
#                 {{- raise_exception("Tool call IDs should be alphanumeric strings with length 9!") }}
#             {%- endif %}
#             {{- ', "id": "' + tool_call.id + '"}' }}
#             {%- if not loop.last %}
#                 {{- ", " }}
#             {%- else %}
#                 {{- "]" + eos_token }}
#             {%- endif %}
#         {%- endfor %}
#     {%- elif message["role"] == "assistant" %}
#         {{- message["content"] + eos_token}}
#     {%- elif message["role"] == "tool_results" or message["role"] == "tool" %}
#         {%- if message.content is defined and message.content.content is defined %}
#             {%- set content = message.content.content %}
#         {%- else %}
#             {%- set content = message.content %}
#         {%- endif %}
#         {{- '[TOOL_RESULTS]{"content": ' + content|string + ", " }}
#         {%- if not message.tool_call_id is defined or message.tool_call_id|length != 9 %}
#             {{- raise_exception("Tool call IDs should be alphanumeric strings with length 9!") }}
#         {%- endif %}
#         {{- '"call_id": "' + message.tool_call_id + '"}[/TOOL_RESULTS]' }}
#     {%- else %}
#         {{- raise_exception("Only user and assistant roles are supported, with the exception of an initial optional system message!") }}
#     {%- endif %}
# {%- endfor %}
#
# INFO:hf-to-gguf:Set model quantization version
# INFO:gguf.gguf_writer:Writing the following files:
# INFO:gguf.gguf_writer:/content/Mistral-Nemo-IT-2407-ORPOall-f16-v3/unsloth.F16.gguf: n_tensors = 363, total_size = 24.5G
# Writing: 100%|██████████| 24.5G/24.5G [02:04<00:00, 197Mbyte/s]
# INFO:hf-to-gguf:Model successfully exported to /content/Mistral-Nemo-IT-2407-ORPOall-f16-v3/unsloth.F16.gguf
# Unsloth: Conversion completed! Output location: /content/Mistral-Nemo-IT-2407-ORPOall-f16-v3/unsloth.F16.gguf
# Unsloth: Uploading GGUF to Huggingface Hub...
#   0%|          | 0/1 [00:00<?, ?it/s]
# unsloth.F16.gguf:   0%|          | 0.00/24.5G [00:00<?, ?B/s]
# Saved GGUF to https://huggingface.co/iecjsu/Mistral-Nemo-IT-2407-ORPOall-f16-v3

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in `llama.cpp` or a UI based system like `GPT4All`. You can install GPT4All by going [here](https://gpt4all.io/index.html).

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/u54VK8m8tk) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Zephyr DPO 2x faster [free Colab](https://colab.research.google.com/drive/15vttTpzzVXv_tJwEk-hIcQ0S9FcEWvwP?usp=sharing)
# 2. Llama 7b 2x faster [free Colab](https://colab.research.google.com/drive/1lBzz5KeZJKXjvivbYvmGarix9Ao6Wxe5?usp=sharing)
# 3. TinyLlama 4x faster full Alpaca 52K in 1 hour [free Colab](https://colab.research.google.com/drive/1AZghoNBQaMDgWJpi4RbffGM1h6raLUj9?usp=sharing)
# 4. CodeLlama 34b 2x faster [A100 on Colab](https://colab.research.google.com/drive/1y7A0AxE3y8gdj4AVkl2aZX47Xu3P1wJT?usp=sharing)
# 5. Mistral 7b [free Kaggle version](https://www.kaggle.com/code/danielhanchen/kaggle-mistral-7b-unsloth-notebook)
# 6. We also did a [blog](https://huggingface.co/blog/unsloth-trl) with 🤗 HuggingFace, and we're in the TRL [docs](https://huggingface.co/docs/trl/main/en/sft_trainer#accelerate-fine-tuning-2x-using-unsloth)!
# 7. `ChatML` for ShareGPT datasets, [conversational notebook](https://colab.research.google.com/drive/1Aau3lgPzeZKQ-98h69CCu1UJcvIBLmy2?usp=sharing)
# 8. Text completions like novel writing [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing)
#
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Support our work if you can! Thanks!
# </div>
